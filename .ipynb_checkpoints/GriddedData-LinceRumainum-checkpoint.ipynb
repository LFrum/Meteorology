# %%
from IPython.core.display import HTML
HTML( open('my_css.css').read() )
# https://anaconda.org/bfiedler/data/1/download/my_css.css
# Out:
# <style>
# div.text_cell_render{
#     background-color: #bcb;
#     }
# .rendered_html code {
#     background-color: #bcb;
#     color: #900;
# }
# .rendered_html pre {
#     background-color: #bcb;
#     color: #900;
# }
# </style>

# %% [markdown]
# v1.4, 13 June 2020, by Brian Fiedler
#
# tested to work with Anaconda Python 3.7
#
# *alternatives to basemap and netcdf4 are included, if you need to activate those alternatives*
#
# # netCDF data of Sea Surface Temperature
#
# Here we will investigate 24 months of monthly-averaged Sea Surface Temperature data, for years 2001 and 2002.
# All 24 months can be visualized here: http://metr1313.net/~bonzo/sst.html
#
#
# You will need the netCDF data file [tos_O1_2001-2002.nc](http://www.unidata.ucar.edu/software/netcdf/examples/tos_O1_2001-2002.nc)
# The file is one of several offered in
# [Example netCDF files](http://www.unidata.ucar.edu/software/netcdf/examples/files.html).
#
# There is nothing particularly special or amazing about this data.
# But it is small and easy to use. And it does show an "El Nino" event in 2002.
#
# The data file was analyzed in a task in [METR 1313](http://metr1313.net/lessons/GriddedData), which you should study a bit.  Here we expand on what was in METR 1313, showing off the benefits of working with an ipython notebook.
#
# We will refer to the average of temperature conditions in January 2001  and January 2002 as defining a "climate" for January.
# Normally, climate averages require more than just an average of two values.  Often approximately 30 Januarys would be required to truly define a "climate" for January.
# But in this educational exercise we keep the data small.  Use your imagination a bit about how your computations would
# be very similar if there were many more years in the data.
#
# When we look at the difference between the data for a month and the climate defined for a month, that
# gives the '''anomaly'''.  Our short data does show a very meaningful anomaly, [an ENSO cycle](http://oceanservice.noaa.gov/facts/ninonina.html)
#
# You should examine my [numpy arrays tutorial](http://metr1313.net/lessons/arrays) before proceeding with this project. You can do that tutorial by
# just typing the examples into a new ipython notebook.
#
# *Because of all the images produced, this notebook may take about a minute to run. *

# %% [markdown]
# # Preparing Anaconda Python
#
# You may need to do the following for your Anaconda installation.
#
# On your Linux or OSX terminal, or Windows Anaconda Prompt enter:
#
# ```
# conda update conda
# conda update anaconda
# conda install netcdf4
# conda install basemap
# ```
# With Anaconda Python 3.7, that should work for you.

# %% [markdown]
# ## A record of my suffering with previous versions
# As of August 6, 2016 with Anaconda Python 3.5 on **Windows 10**, the last command will tell you `basemap` is unavailable.
#
# There is a remedy:
# [Anaconda does not offer basemap for Windows 10 with Python3](http://stackoverflow.com/questions/35716830/basemap-with-python-3-5-anaconda-on-windows)
#
# That link recommends you go to [Unofficial Windows Binaries for Python Extension Packages](http://www.lfd.uci.edu/%7Egohlke/pythonlibs). From there I downloaded `basemap-1.0.8-cp35-none-win_amd64.whl`. Thank you Christoph Gohlke!
#
# The first time I tried the `pip` command, it threw an error about a zip file. The second time, it worked!
#
# ```
# [Anaconda3] C:\Users\brian\Anaconda3>pip install C:\Users\brian\Desktop\4330nb\basemap-1.0.8-cp35-none-win_amd64.whl
# Processing c:\users\brian\desktop\4330nb\basemap-1.0.8-cp35-none-win_amd64.whl
# Installing collected packages: basemap
# Successfully installed basemap-1.0.8
# ```
# As of October 2017, this also might be work, but I have not tried it: https://anaconda.org/conda-forge/basemap
#
# FYI: [official documentation about anaconda packages](http://conda.pydata.org/docs/using/pkgs.html)
#
# **netCDF4 not working to read in the data? See the alternative data source below**
#
# **Basemap still not working? Comment out the ```import Basemap``` statement below**

# %%
import os
import subprocess
#from netCDF4 import Dataset # if not working, comment out, and see alternative below
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# In Summer 2020, [another frustration with basemap](https://stackoverflow.com/questions/58683341/basemap-wont-import-because-epsg-file-or-directory-cant-be-found-macos-ana) emerged.  Hence the following cell, if you need it:

# %%
# With Python 3.7, you probably will not need this cell.
where_epsg = subprocess.getoutput("find `conda info --base` -name epsg")
where_epsg = where_epsg.split('\n')[-1]
where_dir = where_epsg.replace('/epsg','')
print("this is where your epsg file is:", where_dir)
os.environ['PROJ_LIB']=where_dir
# Out:
# this is where your epsg file is: FIND: Parameter format not correct

# %%
# Let's hope this works now.
from mpl_toolkits.basemap import Basemap # comment this out if you cannot install basemap, and see below
# Out:
# ----------------------------------------------------------
# ModuleNotFoundError      Traceback (most recent call last)
# <ipython-input-23-3018a4db1c74> in <module>()
#       1 # Let's hope this works now.
# ----> 2 from mpl_toolkits.basemap import Basemap # comment this out if you cannot install basemap, and see below
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
# Still no basemap module success? Edit to be: needmap=False, and land outlines will not be drawn.
# This is our plotting function. You don't need to understand it.
# No documentation is offered here. Just note the examples following.
#def plotpixels2(lon1d,lat1d,data,lowc=None,hic=None,title=None,
#         startlon=0.,outfile=None,needmap=True,caption=None,dpi=144,
#               sizemult=1):
def plotpixels2(lon1d,lat1d,data,lowc=None,hic=None,title=None,
         startlon=0.,outfile=None,needmap=False,caption=None,dpi=144,
               sizemult=1):
    print('...doing plotpixels:')
    lon1d=np.array(lon1d)
    lat1d=np.array(lat1d)
    delon = lon1d[1]-lon1d[0]
    delat = lat1d[1]-lat1d[0]
    lonp = np.zeros(len(lon1d)+1,'d')
    latp = np.zeros(len(lat1d)+1,'d')
    lonp[0:len(lon1d)] = lon1d-0.5*delon
    lonp[-1] = lon1d[-1]+0.5*delon
    latp[0:len(lat1d)] = lat1d-0.5*delat
    latp[-1] = lat1d[-1]+0.5*delat
    lons, lats = np.meshgrid(lonp, latp)

    if needmap:
        m = Basemap(llcrnrlon=startlon,\
            llcrnrlat=-90,urcrnrlon=startlon+360.,urcrnrlat=90.,\
            resolution='c',area_thresh=10000.,projection='cyl')
        aspectRatio=m.aspect
    else:
        aspectRatio=.5

    xsize = sizemult*plt.rcParams['figure.figsize'][0]
    fig = plt.figure(figsize=(xsize,aspectRatio*xsize))
    # https://matplotlib.org/api/api_changes.html
    # So you may need to replace axisbg with facecolor in the following:
    ax = fig.add_axes([0.08,0.1,0.7,0.7],facecolor='white') # changed to facecolor 8 October 2019

    if needmap:
        x, y = m(lons, lats)
    else:
        x,y=lons,lats
    parallels = np.arange(-90.,90.,30.)
    if startlon==-180:
        meridians = np.arange(-180.,180.,60.)
    else:
        meridians = np.arange(0.,360.,60.)
    colormap=plt.cm.jet

# Pixelate your data!
    if needmap:
        p = m.pcolor(x,y,data,cmap=colormap) 
    else:
        p = plt.pcolor(x,y,data,cmap=colormap)
#        p = plt.pcolor(x,y,data,edgecolors='w',cmap=colormap)

    if title: plt.title(title)
    cax = plt.axes([0.85, 0.1, 0.05, 0.7]) # setup colorbar axes
    datamin=data.min()
    datamax=data.max()
    if lowc==None : lowc=datamin
    if hic==None : hic=datamax
    print('min data: ',datamin,'   max data:',datamax)
    print('low color bound:',lowc,'  high color bound:',hic)
    if  datamin<lowc:
        print("warning: some data below low color bound ")
    if datamax>hic:
        print("warning: some data above high color bound")
    if datamax>1000.:
        plt.colorbar(format='%7.1e', cax=cax) # draw colorbar
    elif datamax>5.:
        plt.colorbar(format='%d', cax=cax) # draw colorbar
    else:
        plt.colorbar(format='%5.2f', cax=cax) # draw colorbar
    plt.axes(ax)  # make the original axes current again
    plt.clim(lowc,hic)
    if needmap:
        m.drawcoastlines()
        m.drawcountries()
        print('overlaying map on pixels')
#        m.drawstates()
    else:
        plt.axis( [ lonp[0], lonp[-1], latp[0], latp[-1] ] )
    if caption: 
        plt.text(-.1,-.15,caption,fontsize=10, transform = plt.gca().transAxes)
    if signature:
        plt.text(-.1,0.,signature,fontsize=48, alpha=.1, transform = plt.gca().transAxes)
    if outfile != None:
        plt.savefig(outfile, dpi=dpi, facecolor='w', edgecolor='w', orientation='portrait')
        print('saved plot to ',outfile,'\n')
        plt.show()
        plt.close()

# %% [markdown]
# ## Read the gridded data into a numpy array
#
# If the netCDF4 module is NOT working for you, the next two cells should
# be replaced with the alternative described below.

# %%
ncpath = 'tos_O1_2001-2002.nc' # path to the netCDF data file
ncfile = Dataset(ncpath, 'r') # make a file handle to read the file
# Out:
# ----------------------------------------------------------
# NameError                Traceback (most recent call last)
# <ipython-input-26-8632ee79526f> in <module>()
#       1 ncpath = 'tos_O1_2001-2002.nc' # path to the netCDF data file
# ----> 2 ncfile = Dataset(ncpath, 'r') # make a file handle to read the file
#
# NameError: name 'Dataset' is not defined

# %% [markdown]
# We copy variable ```tos``` ("temperature of sea") into numpy array `sst`

# %%
sst =   ncfile.variables['tos'][:].astype('float64') 
print("shape of sst:", sst.shape, "   sample:",sst[12,100,100])
lon1d = ncfile.variables['lon'][:] # longitude, 1-D array
print("shape of lon1d:", lon1d.shape,"   sample:",lon1d[100]) 
lat1d = ncfile.variables['lat'][:] # latitude, 1-D array
print("shape of lat1d:", lat1d.shape,"  sample:",lat1d[100])
# Out:
# ----------------------------------------------------------
# NameError                Traceback (most recent call last)
# <ipython-input-27-eea167246db4> in <module>()
# ----> 1 sst =   ncfile.variables['tos'][:].astype('float64')
#       2 print("shape of sst:", sst.shape, "   sample:",sst[12,100,100])
#       3 lon1d = ncfile.variables['lon'][:] # longitude, 1-D array
#       4 print("shape of lon1d:", lon1d.shape,"   sample:",lon1d[100])
#       5 lat1d = ncfile.variables['lat'][:] # latitude, 1-D array
#
# NameError: name 'ncfile' is not defined

# %% [markdown]
# If netCDF4 did not work for you:
# * Get the data files explicitly python, as numpy arrays,  from the this link: [data as numpy arrays](http://metr4330.net/archive/tos_as_numpy_arrays/)
# * I have set the cell below to "raw". Highlight in blue (command mode) and
# * enter letter ```y```, to turn it into executable python.
# (turn it back to raw by entering letter ```r```)
# * In the following, the enormously big numbers are meant to be masked, because it is land. netCDF4 made the mask automatically, in the following the mask is made manually, where the big numbers are.

# %%
# netCDF4 not working for you?
# Get the files as numpy array from the above link.
# I have set this cell to "raw". Highlight in blue (command mode) and
# enter letter y, to turn it into executable python. 
# (turn in back to raw by entering letter r)
# Note big numbers are meant to be masked, because it is land

import numpy as np
sstf = np.load('sst.npy')
print("too big to be a temperature in degrees K ", sstf.max())
sst = np.ma.masked_where(sstf>400, sstf) # big numbers indicate land
print("this should be 305.5:", sst.max())
print("shape of sst:", sst.shape, "   sample:",sst[12,100,100])

lon1d = np.load('lon1d.npy')
print("shape of lon1d:", lon1d.shape,"   sample:",lon1d[100])

lat1d = np.load('lat1d.npy')
print("shape of lat1d:", lat1d.shape,"   sample:",lat1d[100])
# Out:
# too big to be a temperature in degrees K  1.00000002004e+20
# this should be 305.5: 305.503753662
# shape of sst: (24, 170, 180)    sample: 298.795074463
# shape of lon1d: (180,)    sample: 201.0
# shape of lat1d: (170,)    sample: 20.5

# %% [markdown]
# we make the arrays `climate` and `anomaly` from `sst`

# %%
climate = 0.5*( sst[0:12,:,:] + sst[12:,:,:] ) #average the two years
anomaly = sst.copy() # below, we subtract climate
anomaly[0:12,:,:] -= climate # subtract climate from first year
anomaly[12:,:,:] -= climate  # subtract climate from second year

# %%
sst.shape
for i in range(170):
    print(i,lat1d[i])
# Out:
# 0 -79.5
# 1 -78.5
# 2 -77.5
# 3 -76.5
# 4 -75.5
# 5 -74.5
# 6 -73.5
# 7 -72.5
# 8 -71.5
# 9 -70.5
# 10 -69.5
# 11 -68.5
# 12 -67.5
# 13 -66.5
# 14 -65.5
# 15 -64.5
# 16 -63.5
# 17 -62.5
# 18 -61.5
# 19 -60.5
# 20 -59.5
# 21 -58.5
# 22 -57.5
# 23 -56.5
# 24 -55.5
# 25 -54.5
# 26 -53.5
# 27 -52.5
# 28 -51.5
# 29 -50.5
# 30 -49.5
# 31 -48.5
# 32 -47.5
# 33 -46.5
# 34 -45.5
# 35 -44.5
# 36 -43.5
# 37 -42.5
# 38 -41.5
# 39 -40.5
# 40 -39.5
# 41 -38.5
# 42 -37.5
# 43 -36.5
# 44 -35.5
# 45 -34.5
# 46 -33.5
# 47 -32.5
# 48 -31.5
# 49 -30.5
# 50 -29.5
# 51 -28.5
# 52 -27.5
# 53 -26.5
# 54 -25.5
# 55 -24.5
# 56 -23.5
# 57 -22.5
# 58 -21.5
# 59 -20.5
# 60 -19.5
# 61 -18.5
# 62 -17.5
# 63 -16.5
# 64 -15.5
# 65 -14.5
# 66 -13.5
# 67 -12.5
# 68 -11.5
# 69 -10.5
# 70 -9.5
# 71 -8.5
# 72 -7.5
# 73 -6.5
# 74 -5.5
# 75 -4.5
# 76 -3.5
# 77 -2.5
# 78 -1.5
# 79 -0.5
# 80 0.5
# 81 1.5
# 82 2.5
# 83 3.5
# 84 4.5
# 85 5.5
# 86 6.5
# 87 7.5
# 88 8.5
# 89 9.5
# 90 10.5
# 91 11.5
# 92 12.5
# 93 13.5
# 94 14.5
# 95 15.5
# 96 16.5
# 97 17.5
# 98 18.5
# 99 19.5
# 100 20.5
# 101 21.5
# 102 22.5
# 103 23.5
# 104 24.5
# 105 25.5
# 106 26.5
# 107 27.5
# 108 28.5
# 109 29.5
# 110 30.5
# 111 31.5
# 112 32.5
# 113 33.5
# 114 34.5
# 115 35.5
# 116 36.5
# 117 37.5
# 118 38.5
# 119 39.5
# 120 40.5
# 121 41.5
# 122 42.5
# 123 43.5
# 124 44.5
# 125 45.5
# 126 46.5
# 127 47.5
# 128 48.5
# 129 49.5
# 130 50.5
# 131 51.5
# 132 52.5
# 133 53.5
# 134 54.5
# 135 55.5
# 136 56.5
# 137 57.5
# 138 58.5
# 139 59.5
# 140 60.5
# 141 61.5
# 142 62.5
# 143 63.5
# 144 64.5
# 145 65.5
# 146 66.5
# 147 67.5
# 148 68.5
# 149 69.5
# 150 70.5
# 151 71.5
# 152 72.5
# 153 73.5
# 154 74.5
# 155 75.5
# 156 76.5
# 157 77.5
# 158 78.5
# 159 79.5
# 160 80.5
# 161 81.5
# 162 82.5
# 163 83.5
# 164 84.5
# 165 85.5
# 166 86.5
# 167 87.5
# 168 88.5
# 169 89.5

# %% [markdown]
# # The seven 2-D plots from METR 1313

# %%
# My METR 1313 students were required to put a signature on their plots.
signature = "" # use blank string if you don't want a signature
#signature = "plotted by Bonzo" # your name here if you want one

pdir = "bunchofplots/" # name of subdirectory to output plot files into
if not os.path.exists(pdir): os.mkdir(pdir)

# %%
# This function was used for METR 1313 students, 
# to signal to them that they were correct. I will
# leave it here for fun.
def iwant(myval,target):
    print(myval,end="")
    if .999999*target < myval < target*1.000001:
        print("  Value correct!")
    else:
        print("  Wrong! You missed the target:",target)

# %%
# In Summer 2020, I had to suppress those ubiquitous deprecation warnings.
# You can comment out the next two lines and rerun the notebook, if you want the warnings.
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
mytitle="0: January 2001 SST"
data2d = sst[0,:,:] 
iwant( data2d[85,100] , 301.947509766 )

# plotpixels requires: the x coordinates 1-D array,
# the y coordinates 1-D array, a data2d 2-D array,
# with the y-index first (latitude direction) and 
# the x-index second (longitude).
# hic sets the value mapped to the highest color, 
# lowc sets the value mapped to the lowest color
plotpixels2(lon1d, lat1d, data2d, hic=305, lowc=270,
        title = mytitle, outfile=pdir+'Jan2001.png')
# Out:
# 301.947509766  Value correct!
# ...doing plotpixels:
# min data:  271.173248291    max data: 304.678009033
# low color bound: 270   high color bound: 305
# saved plot to  bunchofplots/Jan2001.png

# %%
lat_index = 80 
mytitle = "1: 2001 and 2002 anomaly between 0 and 1 degree"
mycaption = "plotted from pixels centered at latitude %4.1f" \
 % lat1d[lat_index]
data2d = anomaly[:,lat_index,:] # a 2D slice 
iwant( data2d[10,100] , 1.48364257812 )
months = range(data2d.shape[0]) # will be an array containing 0,1,...23
plotpixels2(lon1d, months, data2d, title=mytitle,
    outfile = pdir+'Equator.png', needmap=False, caption=mycaption)
# Note for a Hovmoeller diagram, the x coordinate is longitude
# and y coordinate is months. 
# A map overlay is not possible.
# Also, we choose not to specify hic and lowc. 
# plotpixels selects useful values.

print(data2d.shape)
# Out:
# 1.48364257813  Value correct!
# ...doing plotpixels:
# min data:  -2.91110229492    max data: 2.91110229492
# low color bound: -2.91110229492   high color bound: 2.91110229492
# saved plot to  bunchofplots/Equator.png
# (24, 180)

# %%
mytitle="2: February 2002 SST minus February 2001 SST"
data2d = sst[13,:,:] - sst[1,:,:] # In Python, February is 1 and 13!
iwant( data2d[85,100] , 1.0241394043  )
plotpixels2(lon1d, lat1d, data2d , hic=6, lowc=-6, 
        title=mytitle, outfile=pdir+'FebDiff.png')
# Out:
# 1.0241394043  Value correct!
# ...doing plotpixels:
# min data:  -3.32653808594    max data: 5.95645141602
# low color bound: -6   high color bound: 6
# saved plot to  bunchofplots/FebDiff.png

# %%
# Hint: .mean(0) is a mean over the 0 index,
# which for climate is ALL the 12 months...
mytitle="3: Annual mean of climate" 
data2d = climate[:,:,:].mean(0)  
iwant( data2d[85,100] , 303.308405558 )
plotpixels2(lon1d, lat1d, data2d, hic=305, lowc=270,
    title=mytitle, outfile=pdir+'AnnualMean.png')
# Out:
# 303.308405558  Value correct!
# ...doing plotpixels:
# min data:  271.312257131    max data: 303.682842255
# low color bound: 270   high color bound: 305
# saved plot to  bunchofplots/AnnualMean.png

# %%
# Similar to above, but use the slice syntax with the .mean method.
mytitle="4: January-February-March mean climate"
data2d = climate[0:3,:,:].mean(0) 
iwant( data2d[85,100] , 302.758361816 )
plotpixels2(lon1d, lat1d, data2d , hic=305, lowc=270,
    title=mytitle, outfile=pdir+'JFM.png')
# Out:
# 302.758361816  Value correct!
# ...doing plotpixels:
# min data:  271.318242391    max data: 304.918818156
# low color bound: 270   high color bound: 305
# saved plot to  bunchofplots/JFM.png

# %%
#similar to above
mytitle="5: July-August-September mean climate"
data2d = climate[6:9,:,:].mean(0)
iwant( data2d[85,100] ,303.748860677  )
plotpixels2(lon1d, lat1d, data2d, hic=305, lowc=270,
    title=mytitle, outfile=pdir+'JAS.png')
# Out:
# 303.748860677  Value correct!
# ...doing plotpixels:
# min data:  271.307612101    max data: 304.45018514
# low color bound: 270   high color bound: 305
# saved plot to  bunchofplots/JAS.png

# %%
mytitle="6: Annual range in climate"
print(mytitle)
data2d = climate[:,:,:].max(0) - climate[:,:,:].min(0)
iwant( data2d[85,100] , 1.27612304688  )
plotpixels2(lon1d, lat1d, data2d, hic=25, lowc=0,
    title=mytitle, outfile=pdir+'AnnualRange.png')
# Out:
# 6: Annual range in climate
# 1.27612304688  Value correct!
# ...doing plotpixels:
# min data:  0.035888671875    max data: 23.1513671875
# low color bound: 0   high color bound: 25
# saved plot to  bunchofplots/AnnualRange.png

# %%
mytitle="7: 2001 and 2002 anomaly between 5 S and 5 N"
print(mytitle)
lia=75 # starting latitude index
lib=85 # ending latitude index
mycaption="pixel centers from %5.1f to %5.1f" % ( lat1d[lia],lat1d[lib-1]) 
print(mycaption)
data2d = anomaly[:,lia:lib,:].mean(1) 
iwant( data2d[10,100] , 1.07034301758 )
months = range(data2d.shape[0])
plotpixels2(lon1d, months, data2d, title=mytitle, caption=mycaption,
    outfile=pdir+'5S5N.png',  needmap=False)
# Out:
# 7: 2001 and 2002 anomaly between 5 S and 5 N
# pixel centers from  -4.5 to   4.5
# 1.07034301758  Value correct!
# ...doing plotpixels:
# min data:  -2.24114227295    max data: 2.24114227295
# low color bound: -2.24114227295   high color bound: 2.24114227295
# saved plot to  bunchofplots/5S5N.png

# %% [markdown]
# ## A 1-D plot from METR 1313
# Let's be sure we can make 1-dimensional plots. Just one example here.

# %%
fig,ax = plt.subplots()
lati = 110  
loni = 85
data1d = sst[:,lati,loni] - 273.15 #convert to Celsius
print("the shape of data1d:", data1d.shape )
ax.plot(data1d) # keep it simple
mytitle = "24 months of SST at latitude=%4.1f  longitude=%5.1f" % \
        (lat1d[lati], lon1d[loni])
ax.set_title(mytitle)
ax.set_ylabel('C');
# Out:
# the shape of data1d: (24,)

# %% [markdown]
# <hr style="height:6px;border:none;background-color:#f00;" />
#
# # Student Tasks
#
# At your password-protected website, you need to offer 3 animations,
# like those here http://metr1313.net/~bonzo/sst.html
#
# To make the animations, use [this code](https://code.activestate.com/recipes/580675-makes-html-with-javascript-to-animate-a-sequence-o). Download the python file and name it `janim.py`. Below I show how to `import janim` as a module and use the function `makeanim`.  It is quite simple.
#
# You might feel your ability with numpy arrays is not stressed in this task. This task is more about basic html, uploading files, including zip files, and manipulating this files with the Linux operating system that hosts your website.  You will need to know about [zip and unzip on the Linux command line](http://www.hostingadvice.com/how-to/unzip-file-linuxubuntu/).  If using MobaXterm from Windows, transferring files is simple as dragging and dropping. From OSX, heed my
# [tips here](http://metr1313.net/lessons/Tips#Copying_a_file_to.2Ffrom_your_Mac_or_Linux_PC_from.2Fto_metr1313.net)
#
# Other tasks in METR 4330/5330 will stress expertise with numpy arrays, so hopefully you acquired some ability in this task, even though such ability was not thoroughly tested.

# %%
from janim import makeanim
import glob
from IPython.display import display,clear_output,Image
import time as Time

# %% [markdown]
# Be patient while the loop below runs...

# %%
pngdir = 'sstdir/' # an empty directory with a suitable name
if not os.path.exists(pngdir): os.mkdir(pngdir)
for i in range(24):
    year = 2001 + i//12
    month = i%12 + 1
    plottitle = '%d %d' % (year, month)
    pngname = '%0.4d.png' % i
    print(i,year,month,pngname)
    data2d=sst[i,:,:]
    plotpixels2(lon1d, lat1d, data2d, hic=305, lowc=270,
    title = plottitle, outfile=pngdir+pngname)
# Out:
# 0 2001 1 0000.png
# ...doing plotpixels:
# min data:  271.173248291    max data: 304.678009033
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0000.png
# 1 2001 2 0001.png
# ...doing plotpixels:
# min data:  271.267333984    max data: 304.756561279
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0001.png
# 2 2001 3 0002.png
# ...doing plotpixels:
# min data:  271.309906006    max data: 304.874938965
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0002.png
# 3 2001 4 0003.png
# ...doing plotpixels:
# min data:  271.279510498    max data: 304.460754395
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0003.png
# 4 2001 5 0004.png
# ...doing plotpixels:
# min data:  271.238891602    max data: 304.337371826
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0004.png
# 5 2001 6 0005.png
# ...doing plotpixels:
# min data:  271.215393066    max data: 304.277069092
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0005.png
# 6 2001 7 0006.png
# ...doing plotpixels:
# min data:  271.220031738    max data: 304.146759033
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0006.png
# 7 2001 8 0007.png
# ...doing plotpixels:
# min data:  271.302520752    max data: 304.169952393
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0007.png
# 8 2001 9 0008.png
# ...doing plotpixels:
# min data:  271.298614502    max data: 304.242889404
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0008.png
# 9 2001 10 0009.png
# ...doing plotpixels:
# min data:  271.274841309    max data: 304.243682861
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0009.png
# 10 2001 11 0010.png
# ...doing plotpixels:
# min data:  271.186096191    max data: 303.993469238
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0010.png
# 11 2001 12 0011.png
# ...doing plotpixels:
# min data:  271.17086792    max data: 304.530670166
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0011.png
# 12 2002 1 0012.png
# ...doing plotpixels:
# min data:  271.280578613    max data: 305.409606934
# low color bound: 270   high color bound: 305
# warning: some data above high color bound
# saved plot to  sstdir/0012.png
# 13 2002 2 0013.png
# ...doing plotpixels:
# min data:  271.271362305    max data: 305.503753662
# low color bound: 270   high color bound: 305
# warning: some data above high color bound
# saved plot to  sstdir/0013.png
# 14 2002 3 0014.png
# ...doing plotpixels:
# min data:  271.332672119    max data: 304.976043701
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0014.png
# 15 2002 4 0015.png
# ...doing plotpixels:
# min data:  271.287841797    max data: 304.914642334
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0015.png
# 16 2002 5 0016.png
# ...doing plotpixels:
# min data:  271.24331665    max data: 304.832305908
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0016.png
# 17 2002 6 0017.png
# ...doing plotpixels:
# min data:  271.216888428    max data: 305.08190918
# low color bound: 270   high color bound: 305
# warning: some data above high color bound
# saved plot to  sstdir/0017.png
# 18 2002 7 0018.png
# ...doing plotpixels:
# min data:  271.247375488    max data: 304.860900879
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0018.png
# 19 2002 8 0019.png
# ...doing plotpixels:
# min data:  271.30871582    max data: 305.140960693
# low color bound: 270   high color bound: 305
# warning: some data above high color bound
# saved plot to  sstdir/0019.png
# 20 2002 9 0020.png
# ...doing plotpixels:
# min data:  271.301635742    max data: 305.399688721
# low color bound: 270   high color bound: 305
# warning: some data above high color bound
# saved plot to  sstdir/0020.png
# 21 2002 10 0021.png
# ...doing plotpixels:
# min data:  271.260742188    max data: 304.558563232
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0021.png
# 22 2002 11 0022.png
# ...doing plotpixels:
# min data:  271.206176758    max data: 304.384918213
# low color bound: 270   high color bound: 305
# saved plot to  sstdir/0022.png
# 23 2002 12 0023.png
# ...doing plotpixels:
# min data:  271.190307617    max data: 305.043182373
# low color bound: 270   high color bound: 305
# warning: some data above high color bound
# saved plot to  sstdir/0023.png

# %%
pngs = glob.glob(pngdir+'*.png') # the * matches anything
#if using Windows, get rid of file paths that use \
pngsfixed = [x.replace('\\','/') for x in pngs] # fixes Windows
print(pngs)
print(pngsfixed)
# Out:
# ['sstdir\\0000.png', 'sstdir\\0001.png', 'sstdir\\0002.png', 'sstdir\\0003.png', 'sstdir\\0004.png', 'sstdir\\0005.png', 'sstdir\\0006.png', 'sstdir\\0007.png', 'sstdir\\0008.png', 'sstdir\\0009.png', 'sstdir\\0010.png', 'sstdir\\0011.png', 'sstdir\\0012.png', 'sstdir\\0013.png', 'sstdir\\0014.png', 'sstdir\\0015.png', 'sstdir\\0016.png', 'sstdir\\0017.png', 'sstdir\\0018.png', 'sstdir\\0019.png', 'sstdir\\0020.png', 'sstdir\\0021.png', 'sstdir\\0022.png', 'sstdir\\0023.png']
# ['sstdir/0000.png', 'sstdir/0001.png', 'sstdir/0002.png', 'sstdir/0003.png', 'sstdir/0004.png', 'sstdir/0005.png', 'sstdir/0006.png', 'sstdir/0007.png', 'sstdir/0008.png', 'sstdir/0009.png', 'sstdir/0010.png', 'sstdir/0011.png', 'sstdir/0012.png', 'sstdir/0013.png', 'sstdir/0014.png', 'sstdir/0015.png', 'sstdir/0016.png', 'sstdir/0017.png', 'sstdir/0018.png', 'sstdir/0019.png', 'sstdir/0020.png', 'sstdir/0021.png', 'sstdir/0022.png', 'sstdir/0023.png']

# %% [markdown]
# Below, we show how to display, within the notebook, an animation of saved image files.

# %%
#locally, we use pngs in all OS
pngs.sort() # probably not needed, pngs is already sorted
n=0 #image counter
nloopmax = 3 # set =0 to prevent this cell from running
nloop = 0 #loop counter
while nloop < nloopmax:
    png = pngs[n]
    n+=1
    if n >= len(pngs): #go back to first image
        n = 0
        nloop += 1
    display(Image(filename=png))
    Time.sleep(0.3) # time interval between frames in seconds
    clear_output(wait=True)
print("completed",nloop,"loops of animation")
# Out:
# completed 3 loops of animation

# %% [markdown]
# Next we make the HTML file that can animate the image files.  You will need to make three web pages, one each for `sst` `climate` and `anomaly`

# %%
# note we use pngsfixed here to make the web page
makeanim(pngsfixed,outfile="myanimator.html",sortOrder=True,
         ctlOnSide=True,titlestring="Animation of SST")

# %% [markdown]
# Now open the file you made locally in your browser: [myanimator.html](myanimator.html).  The javascript embedded in the file controls the animation. Make three such animations and offer the animations at your password-protected website.

# %%
pngdirClimate = 'climatedir/' # an empty directory with a suitable name
if not os.path.exists(pngdirClimate): os.mkdir(pngdirClimate)
for i in range(12):
    year = "Average of Year 2001 & 2002 in Month"
    month = i%12 + 1
    plottitle = '%s %i' % (year, month)
    pngname = '%0.4d.png' % i
    print(i,year,month,pngname)
    data2d=climate[i,:,:]
    plotpixels2(lon1d, lat1d, data2d, hic=305, lowc=270,
    title = plottitle, outfile=pngdirClimate+pngname)
# Out:
# 0 Average of Year 2001 & 2002 in Month 1 0000.png
# ...doing plotpixels:
# min data:  271.296768188    max data: 305.043807983
# low color bound: 270   high color bound: 305
# warning: some data above high color bound
# saved plot to  climatedir/0000.png
# 1 Average of Year 2001 & 2002 in Month 2 0001.png
# ...doing plotpixels:
# min data:  271.308074951    max data: 305.07850647
# low color bound: 270   high color bound: 305
# warning: some data above high color bound
# saved plot to  climatedir/0001.png
# 2 Average of Year 2001 & 2002 in Month 3 0002.png
# ...doing plotpixels:
# min data:  271.328643799    max data: 304.897491455
# low color bound: 270   high color bound: 305
# saved plot to  climatedir/0002.png
# 3 Average of Year 2001 & 2002 in Month 4 0003.png
# ...doing plotpixels:
# min data:  271.287658691    max data: 304.51423645
# low color bound: 270   high color bound: 305
# saved plot to  climatedir/0003.png
# 4 Average of Year 2001 & 2002 in Month 5 0004.png
# ...doing plotpixels:
# min data:  271.249237061    max data: 304.364944458
# low color bound: 270   high color bound: 305
# saved plot to  climatedir/0004.png
# 5 Average of Year 2001 & 2002 in Month 6 0005.png
# ...doing plotpixels:
# min data:  271.270584106    max data: 304.255661011
# low color bound: 270   high color bound: 305
# saved plot to  climatedir/0005.png
# 6 Average of Year 2001 & 2002 in Month 7 0006.png
# ...doing plotpixels:
# min data:  271.303283691    max data: 304.395339966
# low color bound: 270   high color bound: 305
# saved plot to  climatedir/0006.png
# 7 Average of Year 2001 & 2002 in Month 8 0007.png
# ...doing plotpixels:
# min data:  271.306716919    max data: 304.328735352
# low color bound: 270   high color bound: 305
# saved plot to  climatedir/0007.png
# 8 Average of Year 2001 & 2002 in Month 9 0008.png
# ...doing plotpixels:
# min data:  271.301589966    max data: 304.626480103
# low color bound: 270   high color bound: 305
# saved plot to  climatedir/0008.png
# 9 Average of Year 2001 & 2002 in Month 10 0009.png
# ...doing plotpixels:
# min data:  271.275817871    max data: 304.320678711
# low color bound: 270   high color bound: 305
# saved plot to  climatedir/0009.png
# 10 Average of Year 2001 & 2002 in Month 11 0010.png
# ...doing plotpixels:
# min data:  271.212188721    max data: 304.163619995
# low color bound: 270   high color bound: 305
# saved plot to  climatedir/0010.png
# 11 Average of Year 2001 & 2002 in Month 12 0011.png
# ...doing plotpixels:
# min data:  271.204849243    max data: 304.78692627
# low color bound: 270   high color bound: 305
# saved plot to  climatedir/0011.png

# %%
pngs = glob.glob(pngdirClimate+'*.png') # the * matches anything
#if using Windows, get rid of file paths that use \
pngsfixed = [x.replace('\\','/') for x in pngs] # fixes Windows
print(pngs)
print(pngsfixed)
# Out:
# ['climatedir\\0000.png', 'climatedir\\0001.png', 'climatedir\\0002.png', 'climatedir\\0003.png', 'climatedir\\0004.png', 'climatedir\\0005.png', 'climatedir\\0006.png', 'climatedir\\0007.png', 'climatedir\\0008.png', 'climatedir\\0009.png', 'climatedir\\0010.png', 'climatedir\\0011.png']
# ['climatedir/0000.png', 'climatedir/0001.png', 'climatedir/0002.png', 'climatedir/0003.png', 'climatedir/0004.png', 'climatedir/0005.png', 'climatedir/0006.png', 'climatedir/0007.png', 'climatedir/0008.png', 'climatedir/0009.png', 'climatedir/0010.png', 'climatedir/0011.png']

# %%
#locally, we use pngs in all OS
pngs.sort() # probably not needed, pngs is already sorted
n=0 #image counter
nloopmax = 3 # set =0 to prevent this cell from running
nloop = 0 #loop counter
while nloop < nloopmax:
    png = pngs[n]
    n+=1
    if n >= len(pngs): #go back to first image
        n = 0
        nloop += 1
    display(Image(filename=png))
    Time.sleep(0.3) # time interval between frames in seconds
    clear_output(wait=True)
print("completed",nloop,"loops of animation")
# Out:
# completed 3 loops of animation

# %%
# note we use pngsfixed here to make the web page
makeanim(pngsfixed,outfile="myanimator-Climate.html",sortOrder=True,
         ctlOnSide=True,titlestring="Animation of Climate")

# %%
pngdirAnomaly = 'anomalydir-updated/' # an empty directory with a suitable name
if not os.path.exists(pngdirAnomaly): os.mkdir(pngdirAnomaly)
for i in range(24):
    year = 2001 + i//12
    month = i%12 + 1
    plottitle = 'SST Anomaly %d %d' % (year, month)
    pngname = '%0.4d.png' % i
    print(i,year,month,pngname)
    data2d=anomaly[i,:,:]
    plotpixels2(lon1d, lat1d, data2d, hic=6, lowc=-6,
    title = plottitle, outfile=pngdirAnomaly+pngname)
# Out:
# 0 2001 1 0000.png
# ...doing plotpixels:
# min data:  -2.91221618652    max data: 1.54777526855
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0000.png
# 1 2001 2 0001.png
# ...doing plotpixels:
# min data:  -2.97822570801    max data: 1.66326904297
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0001.png
# 2 2001 3 0002.png
# ...doing plotpixels:
# min data:  -2.71041870117    max data: 1.60876464844
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0002.png
# 3 2001 4 0003.png
# ...doing plotpixels:
# min data:  -2.34092712402    max data: 1.43188476563
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0003.png
# 4 2001 5 0004.png
# ...doing plotpixels:
# min data:  -2.64059448242    max data: 1.4341583252
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0004.png
# 5 2001 6 0005.png
# ...doing plotpixels:
# min data:  -2.95329284668    max data: 1.64283752441
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0005.png
# 6 2001 7 0006.png
# ...doing plotpixels:
# min data:  -2.64515686035    max data: 2.56326293945
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0006.png
# 7 2001 8 0007.png
# ...doing plotpixels:
# min data:  -2.69200134277    max data: 2.52044677734
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0007.png
# 8 2001 9 0008.png
# ...doing plotpixels:
# min data:  -2.06327819824    max data: 1.73913574219
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0008.png
# 9 2001 10 0009.png
# ...doing plotpixels:
# min data:  -2.05393981934    max data: 2.03038024902
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0009.png
# 10 2001 11 0010.png
# ...doing plotpixels:
# min data:  -1.66590881348    max data: 2.47874450684
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0010.png
# 11 2001 12 0011.png
# ...doing plotpixels:
# min data:  -1.83885192871    max data: 2.46426391602
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0011.png
# 12 2002 1 0012.png
# ...doing plotpixels:
# min data:  -1.54777526855    max data: 2.91221618652
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0012.png
# 13 2002 2 0013.png
# ...doing plotpixels:
# min data:  -1.66326904297    max data: 2.97822570801
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0013.png
# 14 2002 3 0014.png
# ...doing plotpixels:
# min data:  -1.60876464844    max data: 2.71041870117
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0014.png
# 15 2002 4 0015.png
# ...doing plotpixels:
# min data:  -1.43188476563    max data: 2.34092712402
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0015.png
# 16 2002 5 0016.png
# ...doing plotpixels:
# min data:  -1.4341583252    max data: 2.64059448242
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0016.png
# 17 2002 6 0017.png
# ...doing plotpixels:
# min data:  -1.64283752441    max data: 2.95329284668
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0017.png
# 18 2002 7 0018.png
# ...doing plotpixels:
# min data:  -2.56326293945    max data: 2.64515686035
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0018.png
# 19 2002 8 0019.png
# ...doing plotpixels:
# min data:  -2.52044677734    max data: 2.69200134277
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0019.png
# 20 2002 9 0020.png
# ...doing plotpixels:
# min data:  -1.73913574219    max data: 2.06327819824
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0020.png
# 21 2002 10 0021.png
# ...doing plotpixels:
# min data:  -2.03038024902    max data: 2.05393981934
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0021.png
# 22 2002 11 0022.png
# ...doing plotpixels:
# min data:  -2.47874450684    max data: 1.66590881348
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0022.png
# 23 2002 12 0023.png
# ...doing plotpixels:
# min data:  -2.46426391602    max data: 1.83885192871
# low color bound: -6   high color bound: 6
# saved plot to  anomalydir-updated/0023.png

# %%
pngs = glob.glob(pngdirAnomaly+'*.png') # the * matches anything
#if using Windows, get rid of file paths that use \
pngsfixed = [x.replace('\\','/') for x in pngs] # fixes Windows
print(pngs)
print(pngsfixed)
# Out:
# ['anomalydir-updated\\0000.png', 'anomalydir-updated\\0001.png', 'anomalydir-updated\\0002.png', 'anomalydir-updated\\0003.png', 'anomalydir-updated\\0004.png', 'anomalydir-updated\\0005.png', 'anomalydir-updated\\0006.png', 'anomalydir-updated\\0007.png', 'anomalydir-updated\\0008.png', 'anomalydir-updated\\0009.png', 'anomalydir-updated\\0010.png', 'anomalydir-updated\\0011.png', 'anomalydir-updated\\0012.png', 'anomalydir-updated\\0013.png', 'anomalydir-updated\\0014.png', 'anomalydir-updated\\0015.png', 'anomalydir-updated\\0016.png', 'anomalydir-updated\\0017.png', 'anomalydir-updated\\0018.png', 'anomalydir-updated\\0019.png', 'anomalydir-updated\\0020.png', 'anomalydir-updated\\0021.png', 'anomalydir-updated\\0022.png', 'anomalydir-updated\\0023.png']
# ['anomalydir-updated/0000.png', 'anomalydir-updated/0001.png', 'anomalydir-updated/0002.png', 'anomalydir-updated/0003.png', 'anomalydir-updated/0004.png', 'anomalydir-updated/0005.png', 'anomalydir-updated/0006.png', 'anomalydir-updated/0007.png', 'anomalydir-updated/0008.png', 'anomalydir-updated/0009.png', 'anomalydir-updated/0010.png', 'anomalydir-updated/0011.png', 'anomalydir-updated/0012.png', 'anomalydir-updated/0013.png', 'anomalydir-updated/0014.png', 'anomalydir-updated/0015.png', 'anomalydir-updated/0016.png', 'anomalydir-updated/0017.png', 'anomalydir-updated/0018.png', 'anomalydir-updated/0019.png', 'anomalydir-updated/0020.png', 'anomalydir-updated/0021.png', 'anomalydir-updated/0022.png', 'anomalydir-updated/0023.png']

# %%
#locally, we use pngs in all OS
pngs.sort() # probably not needed, pngs is already sorted
n=0 #image counter
nloopmax = 3 # set =0 to prevent this cell from running
nloop = 0 #loop counter
while nloop < nloopmax:
    png = pngs[n]
    n+=1
    if n >= len(pngs): #go back to first image
        n = 0
        nloop += 1
    display(Image(filename=png))
    Time.sleep(0.3) # time interval between frames in seconds
    clear_output(wait=True)
print("completed",nloop,"loops of animation")
# Out:
# completed 3 loops of animation

# %%
# note we use pngsfixed here to make the web page
makeanim(pngsfixed,outfile="myanimator-Anomaly.html",sortOrder=True,
         ctlOnSide=True,titlestring="Animation of Anomaly")

# %%
for i in range(70,71):
    lat_index = i
    data2d = anomaly[:,lat_index,:] # a 2D slice 
    
    print(data2d.shape)
    print(data2d[6,100])
    print(iwant( data2d[6,100] , 1.48364257812 ))
# Out:
# (24, 180)
# -0.2568359375
# -0.2568359375  Wrong! You missed the target: 1.48364257812
# None

# %%
pngdirAnomalyEq = 'anomalydir-Eq/' # an empty directory with a suitable name
if not os.path.exists(pngdirAnomalyEq): os.mkdir(pngdirAnomalyEq)
for i in range(70,90):
    lat_index = i
    mytitle = "2001 and 2002 anomaly between 0 and 1 degree"
    pngname = '%0.4d.png' % i
    mycaption = "plotted from pixels centered at latitude %4.1f" \
    % lat1d[lat_index]
    data2d = anomaly[:,lat_index,:] # a 2D slice 
    iwant( data2d[0,100] , 1.48364257812 )
    months = range(data2d.shape[0]) # will be an array containing 0,1,...23
    plotpixels2(lon1d, months, data2d, title=mytitle,
    outfile = pngdirAnomalyEq+pngname, needmap=False, caption=mycaption)
# Out:
# 0.0320587158203  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -1.57290649414    max data: 1.57290649414
# low color bound: -1.57290649414   high color bound: 1.57290649414
# saved plot to  anomalydir-Eq/0070.png
# 0.00151062011719  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -1.42269897461    max data: 1.42269897461
# low color bound: -1.42269897461   high color bound: 1.42269897461
# saved plot to  anomalydir-Eq/0071.png
# -0.0350036621094  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -1.37173461914    max data: 1.37173461914
# low color bound: -1.37173461914   high color bound: 1.37173461914
# saved plot to  anomalydir-Eq/0072.png
# -0.257171630859  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -1.36625671387    max data: 1.36625671387
# low color bound: -1.36625671387   high color bound: 1.36625671387
# saved plot to  anomalydir-Eq/0073.png
# -0.917984008789  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -1.5950012207    max data: 1.5950012207
# low color bound: -1.5950012207   high color bound: 1.5950012207
# saved plot to  anomalydir-Eq/0074.png
# -1.76797485352  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -1.91981506348    max data: 1.91981506348
# low color bound: -1.91981506348   high color bound: 1.91981506348
# saved plot to  anomalydir-Eq/0075.png
# -2.49864196777  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -2.50428771973    max data: 2.50428771973
# low color bound: -2.50428771973   high color bound: 2.50428771973
# saved plot to  anomalydir-Eq/0076.png
# -2.78268432617  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -2.86741638184    max data: 2.86741638184
# low color bound: -2.86741638184   high color bound: 2.86741638184
# saved plot to  anomalydir-Eq/0077.png
# -2.73115539551  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -2.91221618652    max data: 2.91221618652
# low color bound: -2.91221618652   high color bound: 2.91221618652
# saved plot to  anomalydir-Eq/0078.png
# -2.59812927246  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -2.97822570801    max data: 2.97822570801
# low color bound: -2.97822570801   high color bound: 2.97822570801
# saved plot to  anomalydir-Eq/0079.png
# -2.4462890625  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -2.91110229492    max data: 2.91110229492
# low color bound: -2.91110229492   high color bound: 2.91110229492
# saved plot to  anomalydir-Eq/0080.png
# -2.26942443848  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -2.88708496094    max data: 2.88708496094
# low color bound: -2.88708496094   high color bound: 2.88708496094
# saved plot to  anomalydir-Eq/0081.png
# -1.87355041504  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -2.72326660156    max data: 2.72326660156
# low color bound: -2.72326660156   high color bound: 2.72326660156
# saved plot to  anomalydir-Eq/0082.png
# -1.51593017578  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -2.46383666992    max data: 2.46383666992
# low color bound: -2.46383666992   high color bound: 2.46383666992
# saved plot to  anomalydir-Eq/0083.png
# -1.17485046387  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -2.30781555176    max data: 2.30781555176
# low color bound: -2.30781555176   high color bound: 2.30781555176
# saved plot to  anomalydir-Eq/0084.png
# -0.68603515625  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -2.15473937988    max data: 2.15473937988
# low color bound: -2.15473937988   high color bound: 2.15473937988
# saved plot to  anomalydir-Eq/0085.png
# -0.273468017578  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -1.82359313965    max data: 1.82359313965
# low color bound: -1.82359313965   high color bound: 1.82359313965
# saved plot to  anomalydir-Eq/0086.png
# -0.143615722656  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -1.53302001953    max data: 1.53302001953
# low color bound: -1.53302001953   high color bound: 1.53302001953
# saved plot to  anomalydir-Eq/0087.png
# -0.151840209961  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -1.59544372559    max data: 1.59544372559
# low color bound: -1.59544372559   high color bound: 1.59544372559
# saved plot to  anomalydir-Eq/0088.png
# -0.159576416016  Wrong! You missed the target: 1.48364257812
# ...doing plotpixels:
# min data:  -1.44047546387    max data: 1.44047546387
# low color bound: -1.44047546387   high color bound: 1.44047546387
# saved plot to  anomalydir-Eq/0089.png

# %%
pngdirAnomalyLat = 'anomalydir-Lat/' # an empty directory with a suitable name
if not os.path.exists(pngdirAnomalyLat): os.mkdir(pngdirAnomalyLat)
startLat = 0
endLat = 10
for i in range(0,17):
    #print("startLat: ", startLat)
    #print("endLat: ", endLat)
    #mytitle="2001 and 2002 anomaly between 5 S and 5 N"
    
    if lat1d[startLat] < lat1d[endLat-1]:
        mytitle = "2001 and 2002 anomaly between " + str(lat1d[startLat]) + " and " + str(lat1d[endLat-1])        
    else:
        mytitle = "2001 and 2002 anomaly between " + str(lat1d[endLat-1]) + " and " + str(lat1d[startLat])

    pngname = '%0.4d.png' % i
    mycaption="pixel centers from %5.1f to %5.1f" % ( lat1d[startLat],lat1d[endLat-1]) 
    print(mycaption)
    data2d = anomaly[:,startLat:endLat,:].mean(1) 
    #iwant( data2d[10,100] , 1.07034301758 )
    months = range(data2d.shape[0])
    plotpixels2(lon1d, months, data2d, title=mytitle, caption=mycaption,
        outfile=pngdirAnomalyLat+pngname, needmap=False)
    startLat+=10 # starting latitude index
    endLat+=10 # ending latitude index
# Out:
# pixel centers from -79.5 to -70.5
# ...doing plotpixels:
# min data:  -1.2206993103    max data: 1.2206993103
# low color bound: -1.2206993103   high color bound: 1.2206993103
# saved plot to  anomalydir-Lat/0000.png
# pixel centers from -69.5 to -60.5
# ...doing plotpixels:
# min data:  -0.918864440918    max data: 0.918864440918
# low color bound: -0.918864440918   high color bound: 0.918864440918
# saved plot to  anomalydir-Lat/0001.png
# pixel centers from -59.5 to -50.5
# ...doing plotpixels:
# min data:  -1.23061981201    max data: 1.23061981201
# low color bound: -1.23061981201   high color bound: 1.23061981201
# saved plot to  anomalydir-Lat/0002.png
# pixel centers from -49.5 to -40.5
# ...doing plotpixels:
# min data:  -1.12413024902    max data: 1.12413024902
# low color bound: -1.12413024902   high color bound: 1.12413024902
# saved plot to  anomalydir-Lat/0003.png
# pixel centers from -39.5 to -30.5
# ...doing plotpixels:
# min data:  -1.11036376953    max data: 1.11036376953
# low color bound: -1.11036376953   high color bound: 1.11036376953
# saved plot to  anomalydir-Lat/0004.png
# pixel centers from -29.5 to -20.5
# ...doing plotpixels:
# min data:  -1.09064941406    max data: 1.09064941406
# low color bound: -1.09064941406   high color bound: 1.09064941406
# saved plot to  anomalydir-Lat/0005.png
# pixel centers from -19.5 to -10.5
# ...doing plotpixels:
# min data:  -1.75132751465    max data: 1.75132751465
# low color bound: -1.75132751465   high color bound: 1.75132751465
# saved plot to  anomalydir-Lat/0006.png
# pixel centers from  -9.5 to  -0.5
# ...doing plotpixels:
# min data:  -1.68103790283    max data: 1.68103790283
# low color bound: -1.68103790283   high color bound: 1.68103790283
# saved plot to  anomalydir-Lat/0007.png
# pixel centers from   0.5 to   9.5
# ...doing plotpixels:
# min data:  -1.99909515381    max data: 1.99909515381
# low color bound: -1.99909515381   high color bound: 1.99909515381
# saved plot to  anomalydir-Lat/0008.png
# pixel centers from  10.5 to  19.5
# ...doing plotpixels:
# min data:  -1.09506225586    max data: 1.09506225586
# low color bound: -1.09506225586   high color bound: 1.09506225586
# saved plot to  anomalydir-Lat/0009.png
# pixel centers from  20.5 to  29.5
# ...doing plotpixels:
# min data:  -1.20790100098    max data: 1.20790100098
# low color bound: -1.20790100098   high color bound: 1.20790100098
# saved plot to  anomalydir-Lat/0010.png
# pixel centers from  30.5 to  39.5
# ...doing plotpixels:
# min data:  -1.6369934082    max data: 1.6369934082
# low color bound: -1.6369934082   high color bound: 1.6369934082
# saved plot to  anomalydir-Lat/0011.png
# pixel centers from  40.5 to  49.5
# ...doing plotpixels:
# min data:  -1.90525665283    max data: 1.90525665283
# low color bound: -1.90525665283   high color bound: 1.90525665283
# saved plot to  anomalydir-Lat/0012.png
# pixel centers from  50.5 to  59.5
# ...doing plotpixels:
# min data:  -1.75117492676    max data: 1.75117492676
# low color bound: -1.75117492676   high color bound: 1.75117492676
# saved plot to  anomalydir-Lat/0013.png
# pixel centers from  60.5 to  69.5
# ...doing plotpixels:
# min data:  -2.56326293945    max data: 2.56326293945
# low color bound: -2.56326293945   high color bound: 2.56326293945
# saved plot to  anomalydir-Lat/0014.png
# pixel centers from  70.5 to  79.5
# ...doing plotpixels:
# min data:  -2.17594146729    max data: 2.17594146729
# low color bound: -2.17594146729   high color bound: 2.17594146729
# saved plot to  anomalydir-Lat/0015.png
# pixel centers from  80.5 to  89.5
# ...doing plotpixels:
# min data:  -0.182470703125    max data: 0.182470703125
# low color bound: -0.182470703125   high color bound: 0.182470703125
# saved plot to  anomalydir-Lat/0016.png

# %%
pngs = glob.glob(pngdirAnomalyLat+'*.png') # the * matches anything
#if using Windows, get rid of file paths that use \
pngsfixed = [x.replace('\\','/') for x in pngs] # fixes Windows
print(pngs)
print(pngsfixed)
# Out:
# ['anomalydir-Lat\\0000.png', 'anomalydir-Lat\\0001.png', 'anomalydir-Lat\\0002.png', 'anomalydir-Lat\\0003.png', 'anomalydir-Lat\\0004.png', 'anomalydir-Lat\\0005.png', 'anomalydir-Lat\\0006.png', 'anomalydir-Lat\\0007.png', 'anomalydir-Lat\\0008.png', 'anomalydir-Lat\\0009.png', 'anomalydir-Lat\\0010.png', 'anomalydir-Lat\\0011.png', 'anomalydir-Lat\\0012.png', 'anomalydir-Lat\\0013.png', 'anomalydir-Lat\\0014.png', 'anomalydir-Lat\\0015.png', 'anomalydir-Lat\\0016.png']
# ['anomalydir-Lat/0000.png', 'anomalydir-Lat/0001.png', 'anomalydir-Lat/0002.png', 'anomalydir-Lat/0003.png', 'anomalydir-Lat/0004.png', 'anomalydir-Lat/0005.png', 'anomalydir-Lat/0006.png', 'anomalydir-Lat/0007.png', 'anomalydir-Lat/0008.png', 'anomalydir-Lat/0009.png', 'anomalydir-Lat/0010.png', 'anomalydir-Lat/0011.png', 'anomalydir-Lat/0012.png', 'anomalydir-Lat/0013.png', 'anomalydir-Lat/0014.png', 'anomalydir-Lat/0015.png', 'anomalydir-Lat/0016.png']

# %%
#locally, we use pngs in all OS
pngs.sort() # probably not needed, pngs is already sorted
n=0 #image counter
nloopmax = 3 # set =0 to prevent this cell from running
nloop = 0 #loop counter
while nloop < nloopmax:
    png = pngs[n]
    n+=1
    if n >= len(pngs): #go back to first image
        n = 0
        nloop += 1
    display(Image(filename=png))
    Time.sleep(0.3) # time interval between frames in seconds
    clear_output(wait=True)
print("completed",nloop,"loops of animation")
# Out:
# completed 3 loops of animation

# %%
# note we use pngsfixed here to make the web page
makeanim(pngsfixed,outfile="myanimator-Anomaly-Lat.html",sortOrder=True,
         ctlOnSide=True,titlestring="Animation of Anomaly at Different Latitudes")

# %%
import numpy as np

a = [[5,7,9],[10,12,14]]

b = np.array(a)

print(b)
# Out:
# [[ 5  7  9]
#  [10 12 14]]

# %%
print(b[1][2])
# Out:
# 14

# %%
b[0,0]
# Out:
# 5

# %%
b[1,2]
# Out:
# 14

# %%
b[0,:2]
# Out:
# array([5, 7])

# %%
b[0,:3]
# Out:
# array([5, 7, 9])

# %%
b.mean(0)
# Out:
# array([  7.5,   9.5,  11.5])

# %%
b.mean(1)
# Out:
# array([  7.,  12.])

# %%
np.random.seed(3)

sst=np.random.rand(2,3,4)

print(sst)
# Out:
# [[[ 0.5507979   0.70814782  0.29090474  0.51082761]
#   [ 0.89294695  0.89629309  0.12558531  0.20724288]
#   [ 0.0514672   0.44080984  0.02987621  0.45683322]]
#
#  [[ 0.64914405  0.27848728  0.6762549   0.59086282]
#   [ 0.02398188  0.55885409  0.25925245  0.4151012 ]
#   [ 0.28352508  0.69313792  0.44045372  0.15686774]]]

# %%
np.random.seed(3)

sst=np.random.rand(2)

print(sst)
# Out:
# [ 0.5507979   0.70814782]

# %%
np.random.seed(3)

sst=np.random.rand(2,3)

print(sst)
# Out:
# [[ 0.5507979   0.70814782  0.29090474]
#  [ 0.51082761  0.89294695  0.89629309]]

# %%
climate = np.mean(sst, axis=(1,2))
print(climate)
# Out:
# [ 0.4301444   0.41882693]

# %%
climate.shape
# Out:
# (2,)

# %%
sst.mean(2)
# Out:
# array([[ 0.51516952,  0.53051706,  0.24474662],
#        [ 0.54868726,  0.3142974 ,  0.39349611]])

# %%
anomaly.shape
# Out:
# (2, 3, 4)

# %%
sst.shape
# Out:
# (2, 3, 4)

# %%
anomaly = sst-climate
anomaly.shape
# Out:
# (2, 3, 4)

# %%
climate = sst.mean(0)
climate.shape
# Out:
# (3, 4)

# %%
sst == climate + anomaly
# Out:
# array([[[ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True]],
#
#        [[ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True]]], dtype=bool)

# %%
anomaly[:,0,0]
# Out:
# array([-0.04917307,  0.04917307])

# %%
anomaly[:,-1,-1]
# Out:
# array([ 0.14998274, -0.14998274])

# %%
hovmoller=anomaly[:,0,:]
hovmoller.shape
hovmoller
# Out:
# array([[-0.04917307,  0.21483027, -0.19267508, -0.04001761],
#        [ 0.04917307, -0.21483027,  0.19267508,  0.04001761]])

# %%
hovmoller=anomaly[:,2,:]
hovmoller.shape
# Out:
# (2, 4)

# %%
hovmoller.mean()
# Out:
# 1.3877787807814457e-17

# %%
hovmoller
# Out:
# array([[-0.11602894, -0.12616404, -0.20528875,  0.14998274],
#        [ 0.11602894,  0.12616404,  0.20528875, -0.14998274]])
